# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import world_bank_data as wb
#instalar world_bank_data


 #math 
 #scipy.stats

# %%
#help(pandas.unique)

# %%
importfile = './climate_change.csv'

# %%
df = pd.read_csv(importfile)

# %%
df
# Out:
#     Year        POP        URB        GDP       ENGY     FFEC%    NFFEC%  \
# 0   1960  30.945383   9.331689   0.634565   7.503619  0.940000  0.060000
# 1   1961  31.353506   9.609697   0.661576   7.815869  0.941000  0.059000
# 2   1962  31.910116   9.922943   0.703998   8.233697  0.942000  0.058000
# 3   1963  32.601631  10.268884   0.747172   8.568914  0.944000  0.056000
# 4   1964  33.298713  10.624365   0.810594   8.987576  0.940000  0.060000
# ..   ...        ...        ...        ...        ...       ...       ...
# 57  2017  80.941863  42.561442  42.086316  48.478568  0.821574  0.178773
# 58  2018  81.934807  43.469888  44.545616  48.882321  0.823543  0.176870
# 59  2019  82.907216  44.371691  43.922025  49.296425  0.825514  0.174970
# 60  2020  83.865775  45.271305  38.056959  49.722061  0.827480  0.173081
# 61  2021  84.767584  46.133838  34.618792  50.160409  0.829432  0.171212
#
#          FFEC     NFFEC   CO2E    CO2C  TMPI      TMPA
# ...

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 62

# %%
df.query("Year" == "1964")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df.query("Year" == "1964")
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4108, in DataFrame.query(self, expr, inplace, **kwargs)
#    4106 if not isinstance(expr, str):
#    4107     msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 4108     raise ValueError(msg)
#    4109 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110 kwargs["target"] = None
#
# ValueError: expr must be a string to be evaluated, <class 'bool'> given

# %%
# trasnformar una fecha
pd.to_datetime(df['FECHA'])

df['YEAR']df['FECHA'].dt.year # para crear nuevas columnas con la fecha desglosada, con esto podemos agrupar
